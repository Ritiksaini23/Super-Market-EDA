# %% [markdown]
# <div style="border-radius:10px; border:#DEB887 solid; padding: 15px; background-color: #FFFAF0; font-size:130%; text-align:left">
#
# <h2 align="center"><font color='#DEB887'>Super-Market Exploratory Data Analysis</font></h2>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:100%;
#           text-align:center;">
# Source of Data : Kaggle
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:100%;
#           text-align:center;">
# Technology Used :
#     python libraries(numpy, pandas, matplotlib and seaborn)
# </p>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:100%;
#           text-align:center;">
# Work Flow:
# </p>
# </div>

# %% [markdown]
# - Step 1: Importing the required libraries
# - Step 2: Loading the DataSet
# - Step 3: Basic Understanding of Data

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:90%;
#           text-align:center;">
# Step 1: Importing the Required Libraries
# </p>
# </div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime as dt
import re
import warnings

# Ignore all warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:90%;
#           text-align:center;">
# Step 2: Loading the Data set
# </p>
# </div>

# %%
df= pd.read_csv("C:\\Users\\Ritik\\dataAnalysis\\Data set\\data sets\\supermarket_sales - Sheet1.csv")

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:90%;
#           text-align:center;">
# Step 3: Basic Understanding of Data
# </p>
# </div>

# %% [markdown]
# ### Preview of data

# %%
df.sample(3)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 963  364-34-2972      C  Naypyitaw        Member    Male
# 45   132-32-9879      B   Mandalay        Member  Female
# 449  449-27-2918      B   Mandalay        Member  Female
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 963  Electronic accessories       96.82         3  14.523  304.983  3/30/2019
# 45   Electronic accessories       93.96         4  18.792  394.632   3/9/2019
# 449       Sports and travel       39.12         1   1.956   41.076  3/26/2019
#
#       Time      Payment    cogs  gross margin percentage  gross income  Rating
# 963  20:37         Cash  290.46                 4.761905        14.523     6.7
# 45   18:00         Cash  375.84                 4.761905        18.792     9.5
# 449  11:02  Credit card   39.12                 4.761905         1.956     9.6

# %% [markdown]
# ### How big is the data?

# %%
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# observation:
#     this data is having 1000 rows and 17 columns

# %% [markdown]
# ### Basic information of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# observation:
#
# - all columns are in appropriate type  except date and time so we need to convert them in date time for better analysis
# - this data is having 8 columns of numeric type and 9 columns is of object type
#
# - this data takes 132 kb as memory

# %% [markdown]
# ### fetch column names

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# ### Column Description
#
# - Invoice id: Computer generated sales slip invoice identification number
#
# - Branch: Branch of supercenter (3 branches are available identified by A, B and C).
#
# - City: Location of supercenters
#
# - Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
#
# - Gender: Gender type of customer
#
# - Product line: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
# - Unit price: Price of each product in $
#
# - Quantity: Number of products purchased by customer
#
# - Tax: 5% tax fee for customer buying
#
# - Total: Total price including tax
#
# - Date: Date of purchase (Record available from January 2019 to March 2019)
#
# - Time: Purchase time (10am to 9pm)
#
# - Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
#
# - COGS: Cost of goods sold
#
# - Gross margin percentage: Gross margin percentage
# - Gross income: Gross income
#
# - Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Step 4: Preprocessing
# </p>
# </div>

# %% [markdown]
# ### Detection of missing values

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ##### Observation: this data does not having missing values so dataset seems simple

# %% [markdown]
# ### Detecting the inconsistency  in the data

# %% [markdown]
# ##### seggregation of data into numeric and object  types

# %%
df_obj=df.select_dtypes(include=object)
df_numeric=df.select_dtypes(exclude=object)

# %%
for i in df_obj.columns[1:]:
    print(i,"-------------------",df[i].unique()," has",df[i].nunique(),"values\n\n")
# Out:
# Branch ------------------- ['A' 'C' 'B']  has 3 values
#
#
# City ------------------- ['Yangon' 'Naypyitaw' 'Mandalay']  has 3 values
#
#
# Customer type ------------------- ['Member' 'Normal']  has 2 values
#
#
# Gender ------------------- ['Female' 'Male']  has 2 values
#
#
# Product line ------------------- ['Health and beauty' 'Electronic accessories' 'Home and lifestyle'
#  'Sports and travel' 'Food and beverages' 'Fashion accessories']  has 6 values
#
#
# Date ------------------- ['1/5/2019' '3/8/2019' '3/3/2019' '1/27/2019' '2/8/2019' '3/25/2019'
#  '2/25/2019' '2/24/2019' '1/10/2019' '2/20/2019' '2/6/2019' '3/9/2019'
#  '2/12/2019' '2/7/2019' '3/29/2019' '1/15/2019' '3/11/2019' '1/1/2019'
#  '1/21/2019' '3/5/2019' '3/15/2019' '2/17/2019' '3/2/2019' '3/22/2019'
#  '3/10/2019' '1/25/2019' '1/28/2019' '1/7/2019' '3/23/2019' '1/17/2019'
#  '2/2/2019' '3/4/2019' '3/16/2019' '2/27/2019' '2/10/2019' '3/19/2019'
# ...

# %%
for i in df_numeric.columns:
    for j in df[i].unique():
        if j<=0:
            print("invalid")
            break
else:
    print("no invalid value")
# Out:
# no invalid value

# %% [markdown]
# ##### Observation: from above output we can say there is no invalid and incosistency in numeric type columns and object type columns respectively

# %% [markdown]
# ### Detecting duplicacy

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Observation: there is no duplicacy in the data

# %% [markdown]
# ## Feature engineering

# %%
df.groupby(["Branch"])["City"].unique()
# Out:
# Branch
# A       [Yangon]
# B     [Mandalay]
# C    [Naypyitaw]
# Name: City, dtype: object

# %% [markdown]
# #### since the invoice id is irrelant to the sale analysis and branch and city columns depicting the same information as below:
#
# A :       [Yangon]
#
# B  :    [Mandalay]
#
# C   : [Naypyitaw]
# so we drop them

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.drop(columns=["Invoice ID","Branch"],inplace=True)

# %%
df.shape
# Out:
# (1000, 15)

# %% [markdown]
# ##### since the date and Time in object so convert them in date time

# %%
df["Date"]=pd.to_datetime(df["Date"])
df["Time"]=pd.to_datetime(df["Time"])

# %%
df.dtypes
# Out:
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                       datetime64[ns]
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
df["month"]=df.Date.dt.month_name()
df["day_name"]=df.Date.dt.day_name()
df["day"]=df.Date.dt.day
df["year"]=df.Date.dt.year
df["Hour"]=df.Time.dt.hour

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity   Tax 5%     Total       Date                Time  Payment  \
# 0         7  26.1415  548.9715 2019-01-05 2024-12-08 13:08:00  Ewallet
# 1         5   3.8200   80.2200 2019-03-08 2024-12-08 10:29:00     Cash
#
#      cogs  gross margin percentage  gross income  Rating    month  day_name  \
# 0  522.83                 4.761905       26.1415     9.1  January  Saturday
# 1   76.40                 4.761905        3.8200     9.6    March    Friday
#
#    day  year  Hour
# 0    5  2019    13
# 1    8  2019    10

# %%
df.columns
# Out:
# Index(['City', 'Customer type', 'Gender', 'Product line', 'Unit price',
#        'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating', 'month',
#        'day_name', 'day', 'year', 'Hour'],
#       dtype='object')

# %% [markdown]
# ##### we are dropping gross margin percentage column since it is same for all

# %%
df.drop(columns=["gross margin percentage"],inplace=True)

# %%
df.shape
# Out:
# (1000, 19)

# %%
df.describe().T
# Out:
#                count                        mean                  min  \
# Unit price    1000.0                    55.67213                10.08
# Quantity      1000.0                        5.51                  1.0
# Tax 5%        1000.0                   15.379369               0.5085
# Total         1000.0                  322.966749              10.6785
# Date            1000  2019-02-14 00:05:45.600000  2019-01-01 00:00:00
# Time            1000  2024-12-08 15:24:41.880000  2024-12-08 10:00:00
# cogs          1000.0                   307.58738                10.17
# gross income  1000.0                   15.379369               0.5085
# Rating        1000.0                      6.9727                  4.0
# day           1000.0                      15.256                  1.0
# year          1000.0                      2019.0               2019.0
# Hour          1000.0                       14.91                 10.0
#
# ...

# %%
cols=['Unit price', 'Quantity', 'Tax 5%', 'Total', 'cogs',
       'gross income', 'Rating']
pos=1
plt.figure(figsize=(15,20))
for col in cols:
    plt.subplot(3,3,pos)
    sns.boxplot(x=col,data=df)
    plt.title(col)
    pos=pos+1

# %%
sns.heatmap(df[cols].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##### Since there is strong positive relation with total and quantity and total , cogs, grossincome and tax 5% columns are found to be same so keep only total

# %%
df.columns
# Out:
# Index(['City', 'Customer type', 'Gender', 'Product line', 'Unit price',
#        'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment', 'cogs',
#        'gross income', 'Rating', 'month', 'day_name', 'day', 'year', 'Hour'],
#       dtype='object')

# %%
df.drop(columns=['Tax 5%','gross income','cogs'],inplace=True)

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity     Total       Date                Time  Payment  Rating  \
# 0         7  548.9715 2019-01-05 2024-12-08 13:08:00  Ewallet     9.1
# 1         5   80.2200 2019-03-08 2024-12-08 10:29:00     Cash     9.6
#
#      month  day_name  day  year  Hour
# 0  January  Saturday    5  2019    13
# 1    March    Friday    8  2019    10

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity     Total       Date                Time  Payment  Rating  \
# 0         7  548.9715 2019-01-05 2024-12-08 13:08:00  Ewallet     9.1
# 1         5   80.2200 2019-03-08 2024-12-08 10:29:00     Cash     9.6
#
#      month  day_name  day  year  Hour
# 0  January  Saturday    5  2019    13
# 1    March    Friday    8  2019    10

# %% [markdown]
# ##### Since the Total is our main columns so we do the univaraite analysis

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
sns.distplot(df["Total"])
plt.title("Sale distribution")
plt.subplot(1,2,2)
sns.boxplot(df["Total"])
plt.title("outlier in Total ")
# Out:
# Text(0.5, 1.0, 'outlier in Total ')

# %% [markdown]
# ##### From above output we can say that the distribution is right skewed and outliers present in right side means there were few items which found to be costly which have been purchased by customers and majority of the customers who purchased the items of cost around 150 to 500

# %% [markdown]
# ### Minimum, maximum and average sale of company

# %%
df["Total"].agg(["min","max","mean","sum"]).to_frame()
# Out:
#               Total
# min       10.678500
# max     1042.650000
# mean     322.966749
# sum   322966.749000

# %% [markdown]
# ##### Since the total is having outlier so we can not rely on mean we would be computing median

# %%
x=df["Total"].agg(["min","max","median","sum"]).to_frame()
x
# Out:
#               Total
# min         10.6785
# max       1042.6500
# median     253.8480
# sum     322966.7490

# %%
x.index
# Out:
# Index(['min', 'max', 'median', 'sum'], dtype='object')

# %%
x.values
# Out:
# array([[1.06785000e+01],
#        [1.04265000e+03],
#        [2.53848000e+02],
#        [3.22966749e+05]])

# %%
plt.bar(x.index,x.values[:,0])
# Out:
# <BarContainer object of 4 artists>

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity     Total       Date                Time  Payment  Rating  \
# 0         7  548.9715 2019-01-05 2024-12-08 13:08:00  Ewallet     9.1
# 1         5   80.2200 2019-03-08 2024-12-08 10:29:00     Cash     9.6
#
#      month  day_name  day  year  Hour
# 0  January  Saturday    5  2019    13
# 1    March    Friday    8  2019    10

# %% [markdown]
# ### Which city is more crowded ?

# %%
sns.countplot(x="City",data=df,palette=sns.color_palette("flare"))
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %% [markdown]
# ### City/Branch wise sale

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
sns.barplot(x="City",y="Total",data=df,palette="flare")
plt.title("average sale of each city ",color="Brown",fontsize=20,fontweight="bold")
plt.subplot(1,2,2)
sns.barplot(x="City",y="Total",data=df,estimator=sum,palette="flare")
plt.title("Total sale of each city ",color="Brown",fontsize=20,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Total sale of each city ')

# %% [markdown]
# #### Since Yangon is found to be crowded city but Naypyitaw is found to be hot selling city.

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity     Total       Date                Time  Payment  Rating  \
# 0         7  548.9715 2019-01-05 2024-12-08 13:08:00  Ewallet     9.1
# 1         5   80.2200 2019-03-08 2024-12-08 10:29:00     Cash     9.6
#
#      month  day_name  day  year  Hour
# 0  January  Saturday    5  2019    13
# 1    March    Friday    8  2019    10

# %%
sns.countplot(x="City",data=df,hue="Customer type")
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
sns.barplot(x="City",y="Rating",data=df)
# Out:
# <Axes: xlabel='City', ylabel='Rating'>

# %% [markdown]
# #### Since Naypyitaw is hot selling so find the maximum sale on any day in that city

# %%
df_n=df[df["City"]=="Naypyitaw"]

# %%
df_n[df_n["Total"]==df_n["Total"].max()].T.rename(columns={350:"details"})
# Out:
#                            details
# City                     Naypyitaw
# Customer type               Member
# Gender                      Female
# Product line   Fashion accessories
# Unit price                    99.3
# Quantity                        10
# Total                      1042.65
# Date           2019-02-15 00:00:00
# Time           2024-12-08 14:53:00
# Payment                Credit card
# Rating                         6.6
# month                     February
# day_name                    Friday
# day                             15
# year                          2019
# Hour                            14

# %% [markdown]
# ### Minimum sale on any day in Naypyitaw

# %%
df_n[df_n["Total"]==df_n["Total"].min()].T.rename(columns={822:"details"})
# Out:
#                            details
# City                     Naypyitaw
# Customer type               Member
# Gender                        Male
# Product line     Sports and travel
# Unit price                   10.17
# Quantity                         1
# Total                      10.6785
# Date           2019-02-07 00:00:00
# Time           2024-12-08 14:15:00
# Payment                       Cash
# Rating                         5.9
# month                     February
# day_name                  Thursday
# day                              7
# year                          2019
# Hour                            14

# %% [markdown]
# ### Find the highest business revenue month of the company

# %%
x=df.groupby(["month"])["Total"].agg(["sum"])
x
# Out:
#                  sum
# month
# February   97219.374
# January   116291.868
# March     109455.507

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
sns.barplot(x="month",y="Total",data=df,estimator=sum,palette="flare")
plt.title("Total sale of the company",fontsize=12,color="Red",fontweight="bold")
plt.subplot(1,2,2)
sns.barplot(x="month",y="Total",data=df,palette="flare")
plt.title("Average sale of each month ",fontsize=12,color="Red",fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Average sale of each month ')

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
sns.barplot(x="month",y="Total",data=df,estimator=sum,palette="flare")
plt.title("Total sale of the company",fontsize=12,color="Red",fontweight="bold")
plt.subplot(1,2,2)
plt.pie(x["sum"].values,labels=x.index,autopct="%.2f%%",colors=sns.color_palette("flare"))
plt.title("Hot selling Month of the company % wise  ",fontsize=12,color="Red",fontweight="bold");

# %% [markdown]
# ### Find the highest business revenue month of each City/Branch

# %%
plt.figure(figsize=(15,4),facecolor="pink")
plt.subplot(1,2,1)
sns.barplot(x="City",y="Total",data=df,estimator=sum,palette="Set2",hue="month");
plt.title("Total sale of each city in each month ",fontsize=15,color="brown",fontweight="bold")
plt.subplot(1,2,2)
sns.boxplot(x="City",y="Total",data=df,palette="Set2",hue="month");
plt.title("sale pattern of each city in each month",fontsize=15,color="brown",fontweight="bold");

# %% [markdown]
# ### Sale trend of company over the three months

# %%
plt.figure(figsize=(15,5))
sns.relplot(x="Date",y="Total",data=df,kind="line",color="purple",estimator=sum,ci=False)
plt.xlabel("date")
plt.title(" Company Sale trend over the  3 months ",fontsize=10,color="red",fontweight="bold")
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(15,5))
sns.relplot(x="Date",y="Total",data=df,kind="line",color="purple",estimator=sum,ci=False)
plt.xlabel("date")
plt.title(" Company Sale trend over the  3 months ",fontsize=10,color="red",fontweight="bold")
plt.xticks(rotation=90);

# %%
df_n=df[df["City"]=="Naypyitaw"]
df_y=df[df["City"]=="Yangon"]
df_m=df[df["City"]=="Mandalay"]

# %%
df["City"].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
cities=[df_n,df_y,df_m]
city=["Naypyitaw","Yangon","Mandalay"]
pos=1
plt.figure(figsize=(15,15))
for i in cities:
    plt.subplot(3,1,pos)
    sns.lineplot(x="Date",y="Total",data=i,estimator=sum,ci=False)
    plt.title(f"the sale trend of {city[pos-1]}")
    pos=pos+1

# %% [markdown]
# ### Hot selling day

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="day",y="Total",data=df,estimator=sum,palette="Set2")
plt.xticks(rotation=90)
plt.title("Hot selling day");

# %% [markdown]
# ### Hot selling day of each branch/city

# %%
plt.figure(figsize=(14,15))
pos=1
for df_city in cities:
    #print(city)
    plt.subplot(3,1,pos)
    sns.barplot(x="day",y="Total",data=df_city,estimator=sum,ci=False)
    sns.lineplot(x="day",y="Total",data=df_city,estimator=sum,ci=False)
    plt.title(f"the hot selling day of city {city[pos-1]}")
    
    plt.xticks(rotation=90)
    pos=pos+1

# %% [markdown]
# ### Find Total weekdays sale and weekends sale

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity     Total       Date                Time  Payment  Rating  \
# 0         7  548.9715 2019-01-05 2024-12-08 13:08:00  Ewallet     9.1
# 1         5   80.2200 2019-03-08 2024-12-08 10:29:00     Cash     9.6
#
#      month  day_name  day  year  Hour
# 0  January  Saturday    5  2019    13
# 1    March    Friday    8  2019    10

# %%
df["weekday/weekend"]=df["day_name"].apply(lambda x: "weekend" if ((x=="Saturday") | (x=="Sunday")) else "weekday")

# %%
df.head(3)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2     Yangon        Normal    Male      Home and lifestyle       46.33
#
#    Quantity     Total       Date                Time      Payment  Rating  \
# 0         7  548.9715 2019-01-05 2024-12-08 13:08:00      Ewallet     9.1
# 1         5   80.2200 2019-03-08 2024-12-08 10:29:00         Cash     9.6
# 2         7  340.5255 2019-03-03 2024-12-08 13:23:00  Credit card     7.4
#
#      month  day_name  day  year  Hour weekday/weekend
# 0  January  Saturday    5  2019    13         weekend
# 1    March    Friday    8  2019    10         weekday
# 2    March    Sunday    3  2019    13         weekend

# %%
sns.barplot(x="weekday/weekend",y="Total",data=df,estimator=sum)
# Out:
# <Axes: xlabel='weekday/weekend', ylabel='Total'>

# %%
sns.barplot(x="month",y="Total",data=df,estimator=sum,hue="weekday/weekend")
# Out:
# <Axes: xlabel='month', ylabel='Total'>

# %% [markdown]
# ### Weekday and weekend sale of each branch/City of each month

# %%
df.columns
# Out:
# Index(['City', 'Customer type', 'Gender', 'Product line', 'Unit price',
#        'Quantity', 'Total', 'Date', 'Time', 'Payment', 'Rating', 'month',
#        'day_name', 'day', 'year', 'Hour', 'weekday/weekend'],
#       dtype='object')

# %%
df
# Out:
#           City Customer type  Gender            Product line  Unit price  \
# 0       Yangon        Member  Female       Health and beauty       74.69
# 1    Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2       Yangon        Normal    Male      Home and lifestyle       46.33
# 3       Yangon        Member    Male       Health and beauty       58.22
# 4       Yangon        Normal    Male       Sports and travel       86.31
# 5    Naypyitaw        Normal    Male  Electronic accessories       85.39
# 6       Yangon        Member  Female  Electronic accessories       68.84
# 7    Naypyitaw        Normal  Female      Home and lifestyle       73.56
# 8       Yangon        Member  Female       Health and beauty       36.26
# 9     Mandalay        Member  Female      Food and beverages       54.84
# 10    Mandalay        Member  Female     Fashion accessories       14.48
# 11    Mandalay        Member    Male  Electronic accessories       25.51
# ...

# %%
df["City"].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df_n=df[df["City"]=="Naypyitaw"]
df_y=df[df["City"]=="Yangon"]
df_m=df[df["City"]=="Mandalay"]
cities=[df_n,df_y,df_m]
city=["Naypyitaw","Yangon","Mandalay"]

# %%
plt.figure(figsize=(14,15))
pos=1
for df_city in cities:
    #print(city)
    plt.subplot(3,1,pos)
    sns.barplot(x="month",y="Total",data=df_city,estimator=sum,ci=False,hue="weekday/weekend")
    plt.title(f"the weekday/weekend sale  of each city {city[pos-1]} over all three month ")
    
    pos=pos+1

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity     Total       Date                Time  Payment  Rating  \
# 0         7  548.9715 2019-01-05 2024-12-08 13:08:00  Ewallet     9.1
# 1         5   80.2200 2019-03-08 2024-12-08 10:29:00     Cash     9.6
#
#      month  day_name  day  year  Hour weekday/weekend
# 0  January  Saturday    5  2019    13         weekend
# 1    March    Friday    8  2019    10         weekday

# %% [markdown]
# ### Find most populated product of the company/most demanding

# %%
sns.countplot(x="Product line",data=df,palette="pastel")
plt.xticks(rotation=90);

# %% [markdown]
# ### Most populated product of the each City

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="City",data=df,hue="Product line",palette="bright")
plt.xticks(rotation=90);

# %% [markdown]
# ### Find the most revenue generating product of the company

# %%
sns.barplot(x="Total",y="Product line",estimator=sum,data=df,palette="Set2")
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="City",y="Total",estimator=sum,data=df,palette="Set2",hue="Product line",ci=None)
# Out:
# <Axes: xlabel='City', ylabel='Total'>

# %% [markdown]
# ### Find city  and month wise demand of product detail

# %%
df.groupby(["City","month"])["Product line"].value_counts()
# Out:
# City       month     Product line
# Mandalay   February  Fashion accessories       24
#                      Sports and travel         19
#                      Electronic accessories    19
#                      Food and beverages        17
#                      Health and beauty         16
#                      Home and lifestyle        14
#            January   Sports and travel         23
#                      Fashion accessories       21
#                      Food and beverages        19
#                      Electronic accessories    18
#                      Health and beauty         16
#                      Home and lifestyle        14
#            March     Home and lifestyle        22
#                      Health and beauty         21
#                      Sports and travel         20
#                      Electronic accessories    18
#                      Fashion accessories       17
#                      Food and beverages        14
# ...

# %% [markdown]
# ### Find monthly sale of each product of all branches

# %%
df.groupby(["City","Product line","month"])["Total"].sum().to_frame().style.set_properties(**{'background-color': 'black',
                           'color': 'lawngreen',
                           'border-color': 'white'})
# Out:
# <style type="text/css">
# ...

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity     Total       Date                Time  Payment  Rating  \
# 0         7  548.9715 2019-01-05 2024-12-08 13:08:00  Ewallet     9.1
# 1         5   80.2200 2019-03-08 2024-12-08 10:29:00     Cash     9.6
#
#      month  day_name  day  year  Hour weekday/weekend
# 0  January  Saturday    5  2019    13         weekend
# 1    March    Friday    8  2019    10         weekday

# %% [markdown]
# ### Total customers

# %%
df["Customer type"].count()
# Out:
# 1000

# %%
sns.countplot(x="Customer type",data=df)
# Out:
# <Axes: xlabel='Customer type', ylabel='count'>

# %%
sns.countplot(x="City",data=df,hue="Customer type")
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
sns.barplot(x="City",y="Total",data=df,hue="Customer type")
# Out:
# <Axes: xlabel='City', ylabel='Total'>

# %%
sns.catplot(x="City",y="Total",data=df,hue="Customer type",col="Gender",kind="bar")

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity     Total       Date                Time  Payment  Rating  \
# 0         7  548.9715 2019-01-05 2024-12-08 13:08:00  Ewallet     9.1
# 1         5   80.2200 2019-03-08 2024-12-08 10:29:00     Cash     9.6
#
#      month  day_name  day  year  Hour weekday/weekend
# 0  January  Saturday    5  2019    13         weekend
# 1    March    Friday    8  2019    10         weekday

# %%
sns.catplot(x="City",y="Total",data=df,hue="Payment",kind="bar")

# %%
df.head(2)
# Out:
#         City Customer type  Gender            Product line  Unit price  \
# 0     Yangon        Member  Female       Health and beauty       74.69
# 1  Naypyitaw        Normal  Female  Electronic accessories       15.28
#
#    Quantity     Total       Date                Time  Payment  Rating  \
# 0         7  548.9715 2019-01-05 2024-12-08 13:08:00  Ewallet     9.1
# 1         5   80.2200 2019-03-08 2024-12-08 10:29:00     Cash     9.6
#
#      month  day_name  day  year  Hour weekday/weekend
# 0  January  Saturday    5  2019    13         weekend
# 1    March    Friday    8  2019    10         weekday

# %% [markdown]
# ### Find the peak time of Customers visit at supermarket

# %%
plt.figure(figsize=(17,9))
city_name=["Yangon", 'Naypyitaw', 'Mandalay']
pos=1
plt.figure(figsize=(16,5))
for df_city in cities:
    #print(city)
    plt.subplot(1,3,pos)
    sns.lineplot(x="Hour",y="Total",data=df_city,estimator=sum,ci=False)
    plt.title(f"the trend of hour of city {city_name[pos-1]}")
    plt.xticks(rotation=90)
    pos=pos+1

# %%
city_name=["Yangon", 'Naypyitaw', 'Mandalay']
pos=1
plt.figure(figsize=(17,17))
for city in cities:
    #print(city)
    plt.subplot(3,1,pos)
    sns.lineplot(x="Hour",y="Total",data=city,estimator=sum,ci=False,hue="Product line")
    plt.title(f"the trend of hour of city {city_name[pos-1]}")
    plt.xticks(list(range(10,21)),rotation=90)
    pos=pos+1

# %% [markdown]
# ### Rating

# %%
plt.subplot(1,2,1)
sns.distplot(df["Rating"])
plt.subplot(1,2,2)
sns.boxplot(df["Rating"])
# Out:
# <Axes: >

# %%
sns.barplot(x="City",y="Rating",data=df)
# Out:
# <Axes: xlabel='City', ylabel='Rating'>

# %%
df.groupby(["City"])["Rating"].agg(["max","min","mean"])
# Out:
#             max  min      mean
# City
# Mandalay   10.0  4.0  6.818072
# Naypyitaw  10.0  4.0  7.072866
# Yangon     10.0  4.0  7.027059

# %%
city_name
# Out:
# ['Yangon', 'Naypyitaw', 'Mandalay']

# %%
pos=0
for df_city in cities:
    print(city_name[pos],":",(len(df_city[df_city["Rating"]==10])*100/df_city.shape[0]),"%")
    pos=pos+1
# Out:
# Yangon : 0.3048780487804878 %
# Naypyitaw : 0.29411764705882354 %
# Mandalay : 0.9036144578313253 %

# %%
pos=0
for df_city in cities:
    print(city_name[pos],":",(len(df_city[df_city["Rating"]<=4])*100/df_city.shape[0]),"%")
    pos=pos+1
# Out:
# Yangon : 1.2195121951219512 %
# Naypyitaw : 0.5882352941176471 %
# Mandalay : 1.5060240963855422 %

# %%
sns.barplot(x="City",y="Rating",data=df,hue="Product line")
# Out:
# <Axes: xlabel='City', ylabel='Rating'>

# %% [markdown]
# # Conclusion
#
# - Data refer to the month of January, February and March.
# - While the most shopping was done in January,Gross income was highest in this month.
# -
# There are almost 50% Members and 50% normal buyer.
# - Fashion accessories are most populated.
# - Yangon has the most customers but Naypyitaw is the city that makes the most Gross income.
# - Mandalay and Yangon has almost the same Gross income.
# - Shopping done by women were more than men.
# - Food and beverages are most bought by the Members whereas Electronic accessories were most bought by the Normal.
# - Food and beverages product line has the maximum gross income.
# - E-wallet were the preferred payment method where as there was only slightly difference between E-walled and cash payment.
# - Men generally buy more Health and Beauty products.
# - Women generally Fashion accessories.
# - Weekdays has more Gross income than weekends.
# - Weekdays of Naypyitaw city has more gross income than other 3 states.
